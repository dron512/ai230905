# %%
import pandas as pd
data = pd.read_excel('data.xlsx',index_col='지원번호')
data
# Out:
#       Unnamed: 0   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번             0  채치수  북산고  197   90   85  100  95  85      Python
# 2번             1  정대만  북산고  184   40   35   50  55  25        Java
# 3번             2  송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번             3  서태웅  북산고  187   40   60   70  75  80         NaN
# 5번             4  강백호  북산고  188   15   20   10  35  10         NaN
# 6번             5  변덕규  능남고  202   80  100   95  85  80           C
# 7번             6  황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번             7  윤대협  능남고  190  100   85   90  95  95          C#

# %%
import pandas as pd
data = pd.read_excel('data.xlsx',index_col='지원번호')
data = data[data.columns[1:]]
data
# Out:
#        학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    북산고  197   90   85  100  95  85      Python
# 2번    북산고  184   40   35   50  55  25        Java
# 3번    북산고  168   80   75   70  80  75  Javascript
# 4번    북산고  187   40   60   70  75  80         NaN
# 5번    북산고  188   15   20   10  35  10         NaN
# 6번    능남고  202   80  100   95  85  80           C
# 7번    능남고  188   55   65   45  40  35      PYTHON
# 8번    능남고  190  100   85   90  95  95          C#

# %%
data.to_excel('data.xlsx')

# %%
data.loc['1번']
# Out:
# 학교         북산고
# 키          197
# 국어          90
# 영어          85
# 수학         100
# 과학          95
# 사회          85
# SW특기    Python
# Name: 1번, dtype: object

# %%
data.loc['1번','국어']
# Out:
# 90

# %%
data.loc[['1번','2번']]
# Out:
#        학교    키  국어  영어   수학  과학  사회    SW특기
# 지원번호
# 1번    북산고  197  90  85  100  95  85  Python
# 2번    북산고  184  40  35   50  55  25    Java

# %%
data.loc[['1번','2번'],'국어']
# Out:
# 지원번호
# 1번    90
# 2번    40
# Name: 국어, dtype: int64

# %%
data.loc[['1번','2번'],['국어','영어']]
# Out:
#       국어  영어
# 지원번호
# 1번    90  85
# 2번    40  35

# %%
data.loc['1번':'5번','국어':'영어']
# Out:
#       국어  영어
# 지원번호
# 1번    90  85
# 2번    40  35
# 3번    80  75
# 4번    40  60
# 5번    15  20

# %%
data.shape
# Out:
# (8, 8)

# %%
data.iloc[0,1]
# Out:
# 197

# %%
data.iloc[0]
# Out:
# 학교         북산고
# 키          197
# 국어          90
# 영어          85
# 수학         100
# 과학          95
# 사회          85
# SW특기    Python
# Name: 1번, dtype: object

# %%
data.iloc[[0,1],[2,3]]
# Out:
#       국어  영어
# 지원번호
# 1번    90  85
# 2번    40  35

# %%
data.iloc[0:5,0:3]
# Out:
#        학교    키  국어
# 지원번호
# 1번    북산고  197  90
# 2번    북산고  184  40
# 3번    북산고  168  80
# 4번    북산고  187  40
# 5번    북산고  188  15

# %%
data.iloc[0,3]
# Out:
# 85

# %%
data
# Out:
#        학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    북산고  197   90   85  100  95  85      Python
# 2번    북산고  184   40   35   50  55  25        Java
# 3번    북산고  168   80   75   70  80  75  Javascript
# 4번    북산고  187   40   60   70  75  80         NaN
# 5번    북산고  188   15   20   10  35  10         NaN
# 6번    능남고  202   80  100   95  85  80           C
# 7번    능남고  188   55   65   45  40  35      PYTHON
# 8번    능남고  190  100   85   90  95  95          C#

# %%
data.iloc[0,3]=100

# %%
data
# Out:
#        학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    북산고  197   90  100  100  95  85      Python
# 2번    북산고  184   40   35   50  55  25        Java
# 3번    북산고  168   80   75   70  80  75  Javascript
# 4번    북산고  187   40   60   70  75  80         NaN
# 5번    북산고  188   15   20   10  35  10         NaN
# 6번    능남고  202   80  100   95  85  80           C
# 7번    능남고  188   55   65   45  40  35      PYTHON
# 8번    능남고  190  100   85   90  95  95          C#

# %%
data.loc['1번',data.columns[3]]
# Out:
# 100

# %%
data['20231005']=['대구',30,20,0,0,0,0,0]

# %%
data.loc['9번']=['대구',0,0,0,0,0,0,0,0]

# %%
data
# Out:
#        학교    키   국어   영어   수학  과학  사회        SW특기 20231005
# 지원번호
# 1번    북산고  197   90  100  100  95  85      Python       대구
# 2번    북산고  184   40   35   50  55  25        Java       30
# 3번    북산고  168   80   75   70  80  75  Javascript       20
# 4번    북산고  187   40   60   70  75  80         NaN        0
# 5번    북산고  188   15   20   10  35  10         NaN        0
# 6번    능남고  202   80  100   95  85  80           C        0
# 7번    능남고  188   55   65   45  40  35      PYTHON        0
# 8번    능남고  190  100   85   90  95  95          C#        0
# 9번     대구    0    0    0    0   0   0           0        0

# %%
data
# Out:
#        학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    북산고  197   90  100  100  95  85      Python
# 2번    북산고  184   40   35   50  55  25        Java
# 3번    북산고  168   80   75   70  80  75  Javascript
# 4번    북산고  187   40   60   70  75  80         NaN
# 5번    북산고  188   15   20   10  35  10         NaN
# 6번    능남고  202   80  100   95  85  80           C
# 7번    능남고  188   55   65   45  40  35      PYTHON
# 8번    능남고  190  100   85   90  95  95          C#
